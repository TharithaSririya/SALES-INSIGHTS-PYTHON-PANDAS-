# %% [markdown]
# # Sales Analysis

# %% [markdown]
# #### Import necessary libraries

# %%
import pandas as pd
import os

# %% [markdown]
# #### Merge data from each month into one CSV

# %%
files=[file for file in os.listdir('./project python')]
data_frames = []
for file in files:
    current_data= pd.read_csv("./project python/"+file) 
    data_frames.append(current_data)
all_months_data = pd.concat(data_frames) 
all_months_data.to_csv("all_data.csv", index=False)

# %% [markdown]
# #### Read in updated dataframe

# %%
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### Clean up the data!
#   The first step in this is figuring out what we need to clean. I have found in practice, that you find things you need to clean as you perform operations and get errors. Based on the error, you decide how you should go about cleaning the data

# %% [markdown]
# #### Drop rows of NAN

# %%
#Find NAN
all_data.isna()
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          False    False             False       False       False
# 1           True     True              True        True        True
# 2          False    False             False       False       False
# 3          False    False             False       False       False
# 4          False    False             False       False       False
# ...          ...      ...               ...         ...         ...
# 186845     False    False             False       False       False
# 186846     False    False             False       False       False
# 186847     False    False             False       False       False
# 186848     False    False             False       False       False
# 186849     False    False             False       False       False
#
#         Purchase Address
# 0                  False
# 1                   True
# 2                  False
# 3                  False
# ...

# %%
# Drop NaN values
all_data.dropna(inplace=True)
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# #### Get rid of text in order date column

# %%
all_data=all_data[all_data['Order Date'].str[0:2] !='Or']
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# #### Make columns correct type

# %%
all_data.loc[:,'Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data.loc[:,'Price Each']=pd.to_numeric(all_data['Price Each'])
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1      600.0
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1      700.0
# 186847   259355                      iPhone                1      700.0
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Augment data with additional columns

# %% [markdown]
# #### Add month column

# %%
all_data.loc[:,'month']=all_data['Order Date'].str[0:2] 
all_data.loc[:,'month']=all_data['month'].astype(int)
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1      600.0
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1      700.0
# 186847   259355                      iPhone                1      700.0
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address month
# ...

# %% [markdown]
# #### Add a Sales Column

# %%
all_data.loc[:,'Sales']= all_data['Quantity Ordered']*all_data['Price Each']
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1      600.0
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1      700.0
# 186847   259355                      iPhone                1      700.0
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address month   Sales
# ...

# %% [markdown]
# ## Data Exploration!

# %% [markdown]
# #### 1. What was the best month for sales?How much was earned that month?

# %%
results=all_data.groupby('month').sum()[['Sales','Quantity Ordered']]
results
# Out:
#                 Sales Quantity Ordered
# month
# 1          1822256.73            10903
# 2          2202022.42            13449
# 3          2807100.38            17005
# 4      3390670.240001            20558
# 5      3152606.750001            18667
# 6          2577802.26            15253
# 7          2647775.76            16072
# 8          2244467.88            13448
# 9          2097560.13            13109
# 10     3736726.880001            22703
# 11     3199603.200001            19798
# 12     4613443.340002            28114

# %%
import matplotlib.pyplot as plt
months= range(1,13)
plt.bar(months,results['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('month number')
plt.show()

# %% [markdown]
# #### Add a city column

# %%
def get_city(address):
    return address.split(",")[1]

def get_state(address):
    return address.split(",")[2].split(' ')[1]

all_data.loc[:,'City'] = all_data['Purchase Address'].apply(lambda x: get_city(x)+" "+get_state(x))
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1      600.0
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1      700.0
# 186847   259355                      iPhone                1      700.0
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address month   Sales  \
# ...

# %% [markdown]
# #### 2. Which city had  the highest number of sales?

# %%
Results = all_data.groupby(['City']).sum()
Results
# Out:
#                                                             Order ID  \
# City
#  Atlanta GA        1765641765711765821765891766231766271766341766...
#  Austin TX         1765911766091766741766771766861767011767051767...
#  Boston MA         1765591765661765781765811765851765851766001766...
#  Dallas TX         1765581765691765701765771765961766021766101766...
#  Los Angeles CA    1765601765601765611765671765741765741765761765...
#  New York City NY  1765721765751765791765901765991766131766371766...
#  Portland ME       1767731768791769091770721772301772331772991773...
#  Portland OR       1765831765931766171766421766461766481766621767...
#  San Francisco CA  1765621765651765731765841765861765861765941765...
#  Seattle WA        1765631765681765881766121766241766541766631766...
#
#                                                              Product  \
# City
#  Atlanta GA        USB-C Charging CableLightning Charging CableBo...
# ...

# %%
import matplotlib.pyplot as plt
Cities=Results.index 
plt.bar(Cities,Results['Sales'])
plt.xticks(Cities,rotation='vertical',size=8)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Citie name')
plt.show()

# %% [markdown]
# #### 3. What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
all_data.loc[:,'Order Date'] = pd.to_datetime(all_data['Order Date'])
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1      600.0
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1      700.0
# 186847   259355                      iPhone                1      700.0
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 Order Date                         Purchase Address month  \
# ...

# %%
all_data.loc[:,'Order Date'] = pd.to_datetime(all_data['Order Date'])
all_data.loc[:,'hour']= all_data['Order Date'].dt.hour 
all_data.loc[:,'min']= all_data['Order Date'].dt.minute
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1      600.0
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1      700.0
# 186847   259355                      iPhone                1      700.0
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 Order Date                         Purchase Address month  \
# ...

# %%
# Grouping data by 'hour' and getting counts
hourly_counts = all_data.groupby('hour').count() 
plt.plot(hourly_counts.index,hourly_counts['Quantity Ordered']) 
plt.xticks(hourly_counts.index)
plt.grid()
plt.show()

# %% [markdown]
# #### 4.What products are most often sold together?

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)].copy()
df.loc[:,'Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2 = df[['Order ID', 'Grouped']].drop_duplicates()

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    count.update(Counter(combinations(row.split(','),2))) 

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# #### Which product sold the most?

# %%
product_group = all_data.groupby('Product')['Quantity Ordered'].sum()
plt.bar(product_group.index,product_group.values)
plt.xticks(rotation='vertical', size=8)
plt.xlabel('Product')
plt.ylabel('Quantity Ordered')
plt.title('Total Quantity Ordered for Each Product')
plt.show()
